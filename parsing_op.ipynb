# %% [markdown]
# Load Out
# Pick up the task number from the phrase Solving task:
# Use that task number to find final accuracy
# Programs w/ perfect examples
# Found _ similar programs

# %%
import re

def parse_out_file(filepath):
    with open(filepath, 'r') as f:
        content = f.read()
    
    # Split by the separator lines
    sections = re.split(r'={80,}', content)
    
    results = []
    
    # Process pairs: odd section has task number, even section has data
    for i in range(1, len(sections), 2):
        task_section = sections[i]
        
        # Extract task number from odd section
        task_match = re.search(r'Solving Task:\s*(\w+)', task_section)
        if not task_match:
            continue
        task_number = task_match.group(1)
        
        # Get data from next (even) section
        if i + 1 >= len(sections):
            break
        data_section = sections[i + 1]
        
        # Extract programs with perfect examples
        perfect_match = re.search(r'Programs with perfect examples:\s*(\d+)', data_section)
        perfect_programs = int(perfect_match.group(1)) if perfect_match else None
        
        # Extract found similar programs
        similar_match = re.search(r'Found (\d+) similar programs', data_section)
        similar_programs = int(similar_match.group(1)) if similar_match else None
        
        # Extract final accuracy
        accuracy_match = re.search(r'\[(\d+)/\d+\]\s*\w+:\s*([\d.]+)', data_section)
        final_accuracy = float(accuracy_match.group(2)) if accuracy_match else None
        
        results.append({
            'task_number': task_number,
            'final_accuracy': final_accuracy,
            'perfect_programs': perfect_programs,
            'similar_programs': similar_programs
        })
    
    return results

# Use it
results = parse_out_file('testing_run.out')

# Print results
for r in results:
    print(f"Task: {r['task_number']}, Accuracy: {r['final_accuracy']}, ")
        #   f"Perfect: {r['perfect_programs']}, Similar: {r['similar_programs']}")
# Out:
# Task: 0934a4d8, Accuracy: 0.89,
# Task: 135a2760, Accuracy: 0.94,
# Task: 136b0064, Accuracy: 0.0,
# Task: 13e47133, Accuracy: 0.91,
# Task: 142ca369, Accuracy: 0.9,
# Task: 16b78196, Accuracy: 0.95,
# Task: 16de56c4, Accuracy: 1.0,
# Task: 1818057f, Accuracy: 1.0,
# Task: 195c6913, Accuracy: 0.88,
# Task: 1ae2feb7, Accuracy: 1.0,
# Task: 20270e3b, Accuracy: 0.5,
# Task: 20a9e565, Accuracy: 0.13,
# Task: 21897d95, Accuracy: 0.2,
# Task: 221dfab4, Accuracy: 0.86,
# Task: 247ef758, Accuracy: 0.85,
# Task: 269e22fb, Accuracy: 0.29,
# Task: 271d71e2, Accuracy: 0.7,
# Task: 28a6681f, Accuracy: 0.91,
# Task: 291dc1e1, Accuracy: 0.1,
# Task: 2b83f449, Accuracy: 0.81,
# Task: 2ba387bc, Accuracy: 0.07,
# Task: 2c181942, Accuracy: 0.94,
# Task: 2d0172a1, Accuracy: 0.33,
# Task: 31f7f899, Accuracy: 0.99,
# Task: 332f06d7, Accuracy: 0.98,
# Task: 35ab12c3, Accuracy: 0.89,
# Task: 36a08778, Accuracy: 0.73,
# Task: 38007db0, Accuracy: 1.0,
# Task: 3a25b0d8, Accuracy: 0.74,
# ...

# %%
perfect_count = sum(1 for r in results if r['final_accuracy'] and r['perfect_programs'] == 1.0)
one_accuracy = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] == 1.0)
above_95 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] > 0.95)
above_90 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] > 0.90)
above_50 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] > 0.50)
below_10 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] <0.1)
below_5 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] <0.05)
zero_acc = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] ==0.0)
print(f"\n=== Statistics ===")
print(f"Total tasks: {len(results)}")
print(f"Tasks with perfect programs: {perfect_count}")
print(f"Tasks with accuracy = 1.0: {one_accuracy}")
print(f"Tasks with accuracy > 0.95: {above_95}")
print(f"Tasks with accuracy > 0.90: {above_90}")
print(f"Tasks with accuracy > 0.50: {above_50}")
print(f"Tasks with accuracy < 0.1: {below_10}")
print(f"Tasks with accuracy < 0.05: {below_5}")
print(f"Tasks with zero accuracy: {zero_acc}")
# Out:
# === Statistics ===
# Total tasks: 120
# Tasks with perfect programs: 3
# Tasks with accuracy = 1.0: 12
# Tasks with accuracy > 0.95: 29
# Tasks with accuracy > 0.90: 48
# Tasks with accuracy > 0.50: 87
# Tasks with accuracy < 0.1: 2
# Tasks with accuracy < 0.05: 0
# Tasks with zero accuracy: 0

# %%
perfect_count = sum(1 for r in results if r['perfect_programs'] and r['perfect_programs'] > 0)
above_95 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] >= 0.95)
above_90 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] >= 0.90)
below_10 = sum(1 for r in results if r['final_accuracy'] is not None and r['final_accuracy'] <= 0.1)
below_5 = sum(1 for r in results if r['final_accuracy'] is not None and r['final_accuracy'] <= 0.05)
zero_acc = sum(1 for r in results if r['final_accuracy'] == 0.0)

print(f"\n=== Statistics ===")
print(f"Total tasks: {len(results)}")
print(f"Tasks with perfect programs: {perfect_count}")
print(f"Tasks with accuracy >= 0.95: {above_95}")
print(f"Tasks with accuracy >= 0.90: {above_90}")
print(f"Tasks with accuracy < 0.1: {below_10}")
print(f"Tasks with accuracy < 0.05: {below_5}")
print(f"Tasks with zero accuracy: {zero_acc}")
# Out:
# === Statistics ===
# Total tasks: 120
# Tasks with perfect programs: 7
# Tasks with accuracy >= 0.95: 35
# Tasks with accuracy >= 0.90: 49
# Tasks with accuracy < 0.1: 17
# Tasks with accuracy < 0.05: 14
# Tasks with zero accuracy: 14

# %%
# After getting results
results = parse_out_file('testing_run.out')

# # Print all results first
# for r in results:
#     print(f"Task: {r['task_number']}, Accuracy: {r['final_accuracy']}, Perfect: {r['perfect_programs']}")

# Detailed counts
perfect_count = sum(1 for r in results if r['perfect_programs'] and r['perfect_programs'] > 0)
above_95 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] >= 0.95)
above_90 = sum(1 for r in results if r['final_accuracy'] and r['final_accuracy'] >= 0.90)
below_10 = sum(1 for r in results if r['final_accuracy'] is not None and r['final_accuracy'] <= 0.1)
below_5 = sum(1 for r in results if r['final_accuracy'] is not None and r['final_accuracy'] <= 0.05)
zero_acc = sum(1 for r in results if r['final_accuracy'] == 0.0)

print(f"\n=== Statistics ===")
print(f"Total tasks: {len(results)}")
print(f"Tasks with perfect programs: {perfect_count}")
print(f"Tasks with accuracy >= 0.95: {above_95}")
print(f"Tasks with accuracy >= 0.90: {above_90}")
print(f"Tasks with accuracy <= 0.1: {below_10}")
print(f"Tasks with accuracy <= 0.05: {below_5}")
print(f"Tasks with zero accuracy: {zero_acc}")

# Debug: print tasks with perfect programs
# print(f"\nTasks with perfect programs:")
# for r in results:
#     if r['perfect_programs'] and r['perfect_programs'] > 0:
#         print(f"  {r['task_number']}: {r['perfect_programs']} perfect programs")
# Out:
# === Statistics ===
# Total tasks: 120
# Tasks with perfect programs: 7
# Tasks with accuracy >= 0.95: 35
# Tasks with accuracy >= 0.90: 49
# Tasks with accuracy <= 0.1: 17
# Tasks with accuracy <= 0.05: 14
# Tasks with zero accuracy: 14

# %%
import re

def parse_out_file(filepath):
    with open(filepath, 'r') as f:
        content = f.read()
    
    # Split by the separator lines to get individual task sections
    sections = re.split(r'={80,}', content)
    
    results = []
    
    for section in sections:
        if 'Solving Task:' not in section:
            continue
        
        # Extract task number
        task_match = re.search(r'Solving Task:\s*(\w+)', section)
        if not task_match:
            continue
        task_number = task_match.group(1)
        
        # Extract programs with perfect examples (first occurrence in this section)
        perfect_match = re.search(r'Programs with perfect examples:\s*(\d+)', section)
        perfect_programs = int(perfect_match.group(1)) if perfect_match else None
        
        # Extract found similar programs (first occurrence in this section)
        similar_match = re.search(r'Found (\d+) similar programs', section)
        similar_programs = int(similar_match.group(1)) if similar_match else None
        
        # Extract final accuracy (last line with the pattern in this section)
        accuracy_match = re.search(r'[✓✗]\s*\[\d+/\d+\]\s*\w+:\s*([\d.]+)', section)
        final_accuracy = float(accuracy_match.group(1)) if accuracy_match else None
        
        results.append({
            'task_number': task_number,
            'final_accuracy': final_accuracy,
            'perfect_programs': perfect_programs,
            'similar_programs': similar_programs
        })
    
    return results

# Use it
results = parse_out_file('testing_run.out')

# Print nicely
for r in results:
    print(f"Task: {r['task_number']}, Accuracy: {r['final_accuracy']}, "
          f"Perfect: {r['perfect_programs']}, Similar: {r['similar_programs']}")
# Out:
# Task: 0934a4d8, Accuracy: None, Perfect: None, Similar: None
# Task: 135a2760, Accuracy: None, Perfect: None, Similar: None
# Task: 136b0064, Accuracy: None, Perfect: None, Similar: None
# Task: 13e47133, Accuracy: None, Perfect: None, Similar: None
# Task: 142ca369, Accuracy: None, Perfect: None, Similar: None
# Task: 16b78196, Accuracy: None, Perfect: None, Similar: None
# Task: 16de56c4, Accuracy: None, Perfect: None, Similar: None
# Task: 1818057f, Accuracy: None, Perfect: None, Similar: None
# Task: 195c6913, Accuracy: None, Perfect: None, Similar: None
# Task: 1ae2feb7, Accuracy: None, Perfect: None, Similar: None
# Task: 20270e3b, Accuracy: None, Perfect: None, Similar: None
# Task: 20a9e565, Accuracy: None, Perfect: None, Similar: None
# Task: 21897d95, Accuracy: None, Perfect: None, Similar: None
# Task: 221dfab4, Accuracy: None, Perfect: None, Similar: None
# Task: 247ef758, Accuracy: None, Perfect: None, Similar: None
# ...

# %%
import re

def parse_out_file(filepath):
    with open(filepath, 'r') as f:
        content = f.read()
    
    # Split by the separator lines
    sections = re.split(r'={80,}', content)
    
    results = []
    
    for i, section in enumerate(sections):
        # Debug: print section info
        if 'Solving Task:' in section:
            print(f"\n--- Section {i} ---")
            print(section[:500])  # Print first 500 chars
            print("...")
        
        if 'Solving Task:' not in section:
            continue
        
        # Extract task number
        task_match = re.search(r'Solving Task:\s*(\w+)', section)
        if not task_match:
            continue
        task_number = task_match.group(1)
        
        # Extract programs with perfect examples
        perfect_match = re.search(r'Programs with perfect examples:\s*(\d+)', section)
        perfect_programs = int(perfect_match.group(1)) if perfect_match else None
        print(f"Perfect programs match: {perfect_match}")
        
        # Extract found similar programs
        similar_match = re.search(r'Found (\d+) similar programs', section)
        similar_programs = int(similar_match.group(1)) if similar_match else None
        print(f"Similar programs match: {similar_match}")
        
        # Try different patterns for accuracy
        accuracy_match = re.search(r'\[(\d+)/\d+\]\s*\w+:\s*([\d.]+)', section)
        final_accuracy = float(accuracy_match.group(2)) if accuracy_match else None
        print(f"Accuracy match: {accuracy_match}")
        
        results.append({
            'task_number': task_number,
            'final_accuracy': final_accuracy,
            'perfect_programs': perfect_programs,
            'similar_programs': similar_programs
        })
    
    return results

# Use it
results = parse_out_file('testing_run.out')

# Print results
for r in results:
    print(f"\nTask: {r['task_number']}, Accuracy: {r['final_accuracy']}, "
          f"Perfect: {r['perfect_programs']}, Similar: {r['similar_programs']}")
# Out:
# --- Section 1 ---
#
# Solving Task: 0934a4d8
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# --- Section 3 ---
#
# Solving Task: 135a2760
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# --- Section 5 ---
#
# Solving Task: 136b0064
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# --- Section 7 ---
#
# Solving Task: 13e47133
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# --- Section 9 ---
#
# Solving Task: 142ca369
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# --- Section 11 ---
#
# Solving Task: 16b78196
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# --- Section 13 ---
#
# Solving Task: 16de56c4
#
# ...
# Perfect programs match: None
# Similar programs match: None
# Accuracy match: None
#
# ...

# %%
new = """0934a4d8,False,0.07,
135a2760,False,0.87,
136b0064,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
13e47133,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
142ca369,False,0.90,
16b78196,False,0.95,
16de56c4,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
1818057f,True,1.00,
195c6913,False,0.88,
1ae2feb7,False,0.96,
20270e3b,False,0.50,
20a9e565,False,0.13,
21897d95,False,0.20,
221dfab4,False,0.86,
247ef758,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
269e22fb,False,0.42,
271d71e2,False,0.70,
28a6681f,False,0.91,
291dc1e1,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
2b83f449,False,0.93,
2ba387bc,True,1.00,
2c181942,False,0.94,
2d0172a1,False,0.26,
31f7f899,False,0.94,
332f06d7,False,0.98,
35ab12c3,False,0.89,
36a08778,False,0.73,
38007db0,True,1.00,
3a25b0d8,False,0.74,
3dc255db,False,0.96,
3e6067c3,False,0.96,
409aa875,False,0.97,
446ef5d2,False,0.66,
45a5af55,False,0.24,
4a21e3da,False,0.89,
4c3d4a41,False,0.90,
4c416de3,False,0.95,
4c7dc4dd,False,0.29,
4e34c42c,False,0.52,
53fb4810,False,0.95,
5545f144,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
581f7754,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
58490d8a,False,0.95,
58f5dbd5,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
5961cc34,False,0.91,
5dbc8537,False,0.56,
62593bfd,False,0.98,
64efde09,False,0.88,
65b59efc,False,0.20,
67e490f4,False,0.76,
6e453dd6,False,0.78,
6e4f6532,False,0.88,
6ffbe589,False,0.67,
71e489b6,False,0.89,
7491f3cf,False,0.95,
7666fa5d,False,0.74,
78332cb0,True,1.00,
7b0280bc,False,0.93,
7b3084d4,False,0.09,
7b5033c1,True,1.00,
7b80bb43,False,0.98,
7c66cb00,False,0.95,
7ed72f31,False,0.94,
800d221b,False,0.86,
80a900e0,False,0.92,
8698868d,False,0.59,
88bcf3b4,False,0.93,
88e364bc,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
89565ca0,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
898e7135,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
8b7bacbf,False,0.96,
8b9c3697,False,0.95,
8e5c0c38,False,0.99,
8f215267,False,0.94,
8f3a5a89,False,0.99,
9385bd28,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
97d7923e,False,0.98,
981571dc,False,0.97,
9aaea919,False,0.95,
9bbf930d,False,0.99,
a251c730,False,0.52,
a25697e4,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
a32d8b75,False,0.25,
a395ee82,False,0.92,
a47bf94d,False,0.93,
a6f40cea,False,0.36,
aa4ec2a5,False,0.96,
abc82100,False,0.81,
b0039139,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
b10624e5,False,0.94,
b5ca7ac4,False,0.62,
b6f77b65,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
b99e7126,False,0.97,
b9e38dc0,False,0.78,
bf45cf4b,False,0.43,
c4d067a0,False,0.95,
c7f57c3e,False,0.94,
cb2d8a2c,False,0.89,
cbebaa4b,False,0.89,
d35bdbdc,False,0.77,
d59b0160,False,0.81,
d8e07eb2,False,0.78,
da515329,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
db0c5428,False,0.75,
db695cfb,False,0.94,
dbff022c,False,0.96,
dd6b8c4b,False,0.94,
de809cff,False,0.72,
dfadab01,False,0.63,
e12f9a14,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
e3721c99,False,0.79,
e376de54,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
e8686506,False,0.32,
e87109e9,False,0.25,
edb79dae,False,0.64,
eee78d87,True,1.00,
f560132c,False,0.09,
f931b4a8,False,0.27,
faa9f03d,False,0.92,
fc7cae8d,False,0.30,"""

old = """Task: 0934a4d8, Accuracy: 0.89, 
Task: 135a2760, Accuracy: 0.94, 
Task: 136b0064, Accuracy: 0.0, 
Task: 13e47133, Accuracy: 0.91, 
Task: 142ca369, Accuracy: 0.9, 
Task: 16b78196, Accuracy: 0.95, 
Task: 16de56c4, Accuracy: 1.0, 
Task: 1818057f, Accuracy: 1.0, 
Task: 195c6913, Accuracy: 0.88, 
Task: 1ae2feb7, Accuracy: 1.0, 
Task: 20270e3b, Accuracy: 0.5, 
Task: 20a9e565, Accuracy: 0.13, 
Task: 21897d95, Accuracy: 0.2, 
Task: 221dfab4, Accuracy: 0.86, 
Task: 247ef758, Accuracy: 0.85, 
Task: 269e22fb, Accuracy: 0.29, 
Task: 271d71e2, Accuracy: 0.7, 
Task: 28a6681f, Accuracy: 0.91, 
Task: 291dc1e1, Accuracy: 0.1, 
Task: 2b83f449, Accuracy: 0.81, 
Task: 2ba387bc, Accuracy: 0.07, 
Task: 2c181942, Accuracy: 0.94, 
Task: 2d0172a1, Accuracy: 0.33, 
Task: 31f7f899, Accuracy: 0.99, 
Task: 332f06d7, Accuracy: 0.98, 
Task: 35ab12c3, Accuracy: 0.89, 
Task: 36a08778, Accuracy: 0.73, 
Task: 38007db0, Accuracy: 1.0, 
Task: 3a25b0d8, Accuracy: 0.74, 
Task: 3dc255db, Accuracy: 0.96, 
Task: 3e6067c3, Accuracy: 0.96, 
Task: 409aa875, Accuracy: 0.98, 
Task: 446ef5d2, Accuracy: 0.74, 
Task: 45a5af55, Accuracy: 1.0, 
Task: 4a21e3da, Accuracy: 0.89, 
Task: 4c3d4a41, Accuracy: 1.0, 
Task: 4c416de3, Accuracy: 0.95, 
Task: 4c7dc4dd, Accuracy: 0.29, 
Task: 4e34c42c, Accuracy: 0.14, 
Task: 53fb4810, Accuracy: 0.95, 
Task: 5545f144, Accuracy: 0.0, 
Task: 581f7754, Accuracy: 0.86, 
Task: 58490d8a, Accuracy: 0.95, 
Task: 58f5dbd5, Accuracy: 0.18, 
Task: 5961cc34, Accuracy: 0.0, 
Task: 5dbc8537, Accuracy: 0.56, 
Task: 62593bfd, Accuracy: 0.0, 
Task: 64efde09, Accuracy: 0.88, 
Task: 65b59efc, Accuracy: 0.52, 
Task: 67e490f4, Accuracy: 0.76, 
Task: 6e453dd6, Accuracy: 0.78, 
Task: 6e4f6532, Accuracy: 0.0, 
Task: 6ffbe589, Accuracy: 0.67, 
Task: 71e489b6, Accuracy: 0.0, 
Task: 7491f3cf, Accuracy: 0.0, 
Task: 7666fa5d, Accuracy: 0.74, 
Task: 78332cb0, Accuracy: 1.0, 
Task: 7b0280bc, Accuracy: 0.0, 
Task: 7b3084d4, Accuracy: 0.0, 
Task: 7b5033c1, Accuracy: 1.0, 
Task: 7b80bb43, Accuracy: 0.98, 
Task: 7c66cb00, Accuracy: 0.98, 
Task: 7ed72f31, Accuracy: 0.94, 
Task: 800d221b, Accuracy: 0.79, 
Task: 80a900e0, Accuracy: 0.92, 
Task: 8698868d, Accuracy: 0.59, 
Task: 88bcf3b4, Accuracy: 0.97, 
Task: 88e364bc, Accuracy: 0.98, 
Task: 89565ca0, Accuracy: 0.12, 
Task: 898e7135, Accuracy: 0.15, 
Task: 8b7bacbf, Accuracy: 0.96, 
Task: 8b9c3697, Accuracy: 0.0, 
Task: 8e5c0c38, Accuracy: 0.99, 
Task: 8f215267, Accuracy: 0.94, 
Task: 8f3a5a89, Accuracy: 0.68, 
Task: 9385bd28, Accuracy: 0.74, 
Task: 97d7923e, Accuracy: 0.99, 
Task: 981571dc, Accuracy: 0.97, 
Task: 9aaea919, Accuracy: 0.95, 
Task: 9bbf930d, Accuracy: 0.99, 
Task: a251c730, Accuracy: 0.52, 
Task: a25697e4, Accuracy: 0.97, 
Task: a32d8b75, Accuracy: 0.25, 
Task: a395ee82, Accuracy: 0.92, 
Task: a47bf94d, Accuracy: 0.93, 
Task: a6f40cea, Accuracy: 0.36, 
Task: aa4ec2a5, Accuracy: 0.71, 
Task: abc82100, Accuracy: 0.81, 
Task: b0039139, Accuracy: 0.12, 
Task: b10624e5, Accuracy: 0.94, 
Task: b5ca7ac4, Accuracy: 0.62, 
Task: b6f77b65, Accuracy: 0.76, 
Task: b99e7126, Accuracy: 0.97, 
Task: b9e38dc0, Accuracy: 0.78, 
Task: bf45cf4b, Accuracy: 0.22, 
Task: c4d067a0, Accuracy: 1.0, 
Task: c7f57c3e, Accuracy: 0.94, 
Task: cb2d8a2c, Accuracy: 0.89, 
Task: cbebaa4b, Accuracy: 0.89, 
Task: d35bdbdc, Accuracy: 1.0, 
Task: d59b0160, Accuracy: 0.0, 
Task: d8e07eb2, Accuracy: 0.78, 
Task: da515329, Accuracy: 0.64, 
Task: db0c5428, Accuracy: 1.0, 
Task: db695cfb, Accuracy: 0.94, 
Task: dbff022c, Accuracy: 0.95, 
Task: dd6b8c4b, Accuracy: 0.0, 
Task: de809cff, Accuracy: 0.72, 
Task: dfadab01, Accuracy: 0.0, 
Task: e12f9a14, Accuracy: 0.88, 
Task: e3721c99, Accuracy: 0.79, 
Task: e376de54, Accuracy: 0.96, 
Task: e8686506, Accuracy: 0.32, 
Task: e87109e9, Accuracy: 0.0, 
Task: edb79dae, Accuracy: 0.64, 
Task: eee78d87, Accuracy: 1.0, 
Task: f560132c, Accuracy: 0.09, 
Task: f931b4a8, Accuracy: 0.8, 
Task: faa9f03d, Accuracy: 0.92, 
Task: fc7cae8d, Accuracy: 0.3,"""

new_dict = {line.split(',')[0]: float(line.split(',')[2]) for line in new.strip().split('\n') if len(line.split(',')) > 2 and line.split(',')[2].strip()}
old_dict = {line.split(',')[0]: float(line.split(',')[2]) for line in old.strip().split('\n') if len(line.split(',')) > 2 and line.split(',')[2].strip()}
for task in old_dict:
    if task in new_dict:
        print(f"{task}: {old_dict[task]:.2f} -> {new_dict[task]:.2f} (Δ {new_dict[task]-old_dict[task]:+.2f})")

# %% [markdown]
# 0934a4d8,False,0.07,
# 135a2760,False,0.87,
# 136b0064,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 13e47133,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 142ca369,False,0.90,
# 16b78196,False,0.95,
# 16de56c4,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 1818057f,True,1.00,
# 195c6913,False,0.88,
# 1ae2feb7,False,0.96,
# 20270e3b,False,0.50,
# 20a9e565,False,0.13,
# 21897d95,False,0.20,
# 221dfab4,False,0.86,
# 247ef758,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 269e22fb,False,0.42,
# 271d71e2,False,0.70,
# 28a6681f,False,0.91,
# 291dc1e1,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 2b83f449,False,0.93,
# 2ba387bc,True,1.00,
# 2c181942,False,0.94,
# 2d0172a1,False,0.26,
# 31f7f899,False,0.94,
# 332f06d7,False,0.98,
# 35ab12c3,False,0.89,
# 36a08778,False,0.73,
# 38007db0,True,1.00,
# 3a25b0d8,False,0.74,
# 3dc255db,False,0.96,
# 3e6067c3,False,0.96,
# 409aa875,False,0.97,
# 446ef5d2,False,0.66,
# 45a5af55,False,0.24,
# 4a21e3da,False,0.89,
# 4c3d4a41,False,0.90,
# 4c416de3,False,0.95,
# 4c7dc4dd,False,0.29,
# 4e34c42c,False,0.52,
# 53fb4810,False,0.95,
# 5545f144,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 581f7754,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 58490d8a,False,0.95,
# 58f5dbd5,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 5961cc34,False,0.91,
# 5dbc8537,False,0.56,
# 62593bfd,False,0.98,
# 64efde09,False,0.88,
# 65b59efc,False,0.20,
# 67e490f4,False,0.76,
# 6e453dd6,False,0.78,
# 6e4f6532,False,0.88,
# 6ffbe589,False,0.67,
# 71e489b6,False,0.89,
# 7491f3cf,False,0.95,
# 7666fa5d,False,0.74,
# 78332cb0,True,1.00,
# 7b0280bc,False,0.93,
# 7b3084d4,False,0.09,
# 7b5033c1,True,1.00,
# 7b80bb43,False,0.98,
# 7c66cb00,False,0.95,
# 7ed72f31,False,0.94,
# 800d221b,False,0.86,
# 80a900e0,False,0.92,
# 8698868d,False,0.59,
# 88bcf3b4,False,0.93,
# 88e364bc,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 89565ca0,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 898e7135,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 8b7bacbf,False,0.96,
# 8b9c3697,False,0.95,
# 8e5c0c38,False,0.99,
# 8f215267,False,0.94,
# 8f3a5a89,False,0.99,
# 9385bd28,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# 97d7923e,False,0.98,
# 981571dc,False,0.97,
# 9aaea919,False,0.95,
# 9bbf930d,False,0.99,
# a251c730,False,0.52,
# a25697e4,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# a32d8b75,False,0.25,
# a395ee82,False,0.92,
# a47bf94d,False,0.93,
# a6f40cea,False,0.36,
# aa4ec2a5,False,0.96,
# abc82100,False,0.81,
# b0039139,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# b10624e5,False,0.94,
# b5ca7ac4,False,0.62,
# b6f77b65,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# b99e7126,False,0.97,
# b9e38dc0,False,0.78,
# bf45cf4b,False,0.43,
# c4d067a0,False,0.95,
# c7f57c3e,False,0.94,
# cb2d8a2c,False,0.89,
# cbebaa4b,False,0.89,
# d35bdbdc,False,0.77,
# d59b0160,False,0.81,
# d8e07eb2,False,0.78,
# da515329,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# db0c5428,False,0.75,
# db695cfb,False,0.94,
# dbff022c,False,0.96,
# dd6b8c4b,False,0.94,
# de809cff,False,0.72,
# dfadab01,False,0.63,
# e12f9a14,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# e3721c99,False,0.79,
# e376de54,False,0.00,"HTTPSConnectionPool(host='api.x.ai', port=443): Read timed out. (read timeout=240)"
# e8686506,False,0.32,
# e87109e9,False,0.25,
# edb79dae,False,0.64,
# eee78d87,True,1.00,
# f560132c,False,0.09,
# f931b4a8,False,0.27,
# faa9f03d,False,0.92,
# fc7cae8d,False,0.30,
