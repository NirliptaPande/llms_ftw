# %%
from utils.dsl import *
from utils.constants import *
import json
import re
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# ## Manual Verification: Test a Single Solver Function
#
# Use the cells below to manually test one solver function on a specific example of a specific task.
#
# **Configure these variables:**
# - `task_id`: The ARC task identifier (e.g., '0934a4d8')
# - `example_index`: Which example to test (0-based index)
# - `test_or_train`: Dataset to use ('train' or 'test')
# - Paste your solver function into the `solve()` function below

# %%
def solve(I):
    # Paste solver function here
    pass

# %%
task_id = 'insert_task_id_here'
example_index = 0
test_or_train = 'test' # 'train' or 'test'

def open_and_solve_example(task_id, example_index, solver, set='train'):
    path = Path(f'../data_v2/evaluation/{task_id}.json')
    if not path.exists():
        print(f"Error processing {task_id} example {example_index}")
        return None, None, None
    try:
        with path.open('r', encoding='utf-8') as f:
            task = json.load(f)
        I = tuple(tuple(row) for row in task[set][example_index]['input'])
        expected = task[set][example_index]['output']
        output = solver(I)
        return I, expected, output
    except Exception:
        print(f"Error processing {task_id} example {example_index}")
        return None, None, None

def verify_output(expected, output):
    if expected == None or output == None:
        print("No output to verify")
        return
    if np.array_equal(np.array(expected), np.array(output)):
        print("Output matches expected!")
    else:
        print("Output does NOT match expected.")
        print("Expected:")
        print(np.array(expected))
        print("Got:")
        print(np.array(output))

# %%
# Run programs and verify if output matches
input, expected, output = open_and_solve_example(task_id, example_index, solve, set=test_or_train)
verify_output(expected, output)
# Out:
# Error processing insert_task_id_here example 0
# No output to verify

# %% [markdown]
# ## Batch Verification: Test All Solver Functions from Log Files
#
# Automatically extracts and tests solver functions from log files on both train and test datasets.
#
# **Configure these variables:**
# - `logs_dir`: Path to directory containing log files with solver functions
# - `test_these_examples`: Range of examples indices to test (e.g., range(0, 6) tests indices 0-5)
#
# The script will:
# 1. Extract solver functions from summary files in the log directory
# 2. Test each function on all specified examples indices for both train and test sets of all tasks
# 3. Print detailed results and summary statistics for each dataset

# %%
# Specify directory containing log files
logs_dir = Path('../logs/exp_name:testing_noreasoning_nodsl_k4_similar_fewshot_repair')
# Settings
test_these_examples = range(0, 6)  # Test indices 0 to 5

# Find all summary files
summary_files = [f for f in logs_dir.glob('*.txt') if 'selection' in f.name]
print(f"Found {len(summary_files)} summary files")

def test_solver_on_dataset(summary_files, dataset_type, test_these_examples):
    """Test all solver functions on a specific dataset (train or test)."""
    # Track results per file across all indices
    file_results = {}
    
    for file_path in summary_files:
        filename = file_path.name
        task_id_local = filename.split('_')[0]
        
        file_results[filename] = {
            'executed_all': True,
            'correct_all': True,
            'results_per_index': {}
        }
        
        try:
            # Read the file content
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read()
            
            # Load task to check available tasks
            try:
                with open(f'../data_v2/evaluation/{task_id_local}.json') as f:
                    task = json.load(f)
            except FileNotFoundError:
                print(f"Skipping {filename}: task file not found")
                file_results[filename]['executed_all'] = False
                file_results[filename]['correct_all'] = False
                continue
            
            # Extract solver function code
            gen_code_idx = content.find('CODE:')
            if gen_code_idx == -1: 
                print(f"Skipping {filename}: markers not found")
                file_results[filename]['executed_all'] = False
                file_results[filename]['correct_all'] = False
                continue
            
            code_section = content[gen_code_idx:]
            def_match = re.search(r'\bdef\s+\w+', code_section)
            
            if not def_match:
                print(f"Skipping {filename}: no function definition found")
                file_results[filename]['executed_all'] = False
                file_results[filename]['correct_all'] = False
                continue
            
            # Extract function body
            def_start = def_match.start()
            return_matches = list(re.finditer(r'\n\s*return\s+.*', code_section[def_start:]))
            
            if not return_matches:
                print(f"Skipping {filename}: no return statement found")
                file_results[filename]['executed_all'] = False
                file_results[filename]['correct_all'] = False
                continue
            
            last_return = return_matches[-1]
            function_end = def_start + last_return.end()
            solver_code = code_section[def_start:function_end]
            
            # Create a fresh namespace with all globals for this solver
            exec_namespace = dict(globals())
            
            # Execute the solver function
            exec(solver_code, exec_namespace)
            func_name_match = re.search(r'def\s+(\w+)', solver_code)
            
            if not func_name_match:
                print(f"Skipping {filename}: could not extract function name")
                file_results[filename]['executed_all'] = False
                file_results[filename]['correct_all'] = False
                continue
            
            func_name = func_name_match.group(1)
            solver_func = exec_namespace[func_name]
            
            # Test across all task indices
            print(f"\nTesting {filename}:")
            for test_task_index in test_these_examples:
                # Check if task_index exists
                if len(task[dataset_type]) <= test_task_index:
                    print(f"  Index {test_task_index}: SKIP (not available)")
                    file_results[filename]['results_per_index'][test_task_index] = {
                        'executed': False,
                        'correct': False,
                        'skipped': True
                    }
                    continue
                
                try:
                    # Solve task
                    I, expected, output = open_and_solve_example(task_id_local, test_task_index, solver_func, set=dataset_type)
                    
                    # Check if output matches expected
                    diffs = np.where(np.array(expected) != np.array(output))
                    is_correct = not diffs[0].size
                    
                    file_results[filename]['results_per_index'][test_task_index] = {
                        'executed': True,
                        'correct': is_correct,
                        'skipped': False
                    }
                    
                    if is_correct:
                        print(f"  Index {test_task_index}: ✓ Correct")
                    else:
                        print(f"  Index {test_task_index}: ✗ Incorrect")
                        file_results[filename]['correct_all'] = False
                        
                except Exception as e:
                    print(f"  Index {test_task_index}: ✗ Error - {type(e).__name__}")
                    file_results[filename]['results_per_index'][test_task_index] = {
                        'executed': False,
                        'correct': False,
                        'skipped': False
                    }
                    file_results[filename]['executed_all'] = False
                    file_results[filename]['correct_all'] = False
                    
        except Exception as e:
            print(f"✗ {filename}: Fatal error - {type(e).__name__}: {str(e)[:100]}")
            file_results[filename]['executed_all'] = False
            file_results[filename]['correct_all'] = False
    
    return file_results

def print_summary(file_results, dataset_type, test_these_examples, total_files):
    """Print summary statistics for a dataset."""
    files_executed_all = sum(1 for r in file_results.values() if r['executed_all'])
    files_correct_all = sum(1 for r in file_results.values() if r['correct_all'])
    
    # Per-index statistics
    per_index_stats = {}
    for idx in test_these_examples:
        executed = sum(1 for r in file_results.values() if idx in r['results_per_index'] and r['results_per_index'][idx]['executed'])
        correct = sum(1 for r in file_results.values() if idx in r['results_per_index'] and r['results_per_index'][idx]['correct'])
        skipped = sum(1 for r in file_results.values() if idx in r['results_per_index'] and r['results_per_index'][idx]['skipped'])
        per_index_stats[idx] = {'executed': executed, 'correct': correct, 'skipped': skipped}
    
    print(f"\n{'='*60}")
    print(f"SUMMARY FOR {dataset_type.upper()} SET:")
    print(f"{'='*60}")
    print(f"Total files: {total_files}")
    print(f"Programs that executed without error for all examples: {files_executed_all}")
    print(f"Programs with correct output for all examples: {files_correct_all}")
    print(f"\nPER-EXAMPLE-INDEX BREAKDOWN:")
    for idx in test_these_examples:
        stats = per_index_stats[idx]
        print(f"  Index {idx}: {stats['executed']} executed, {stats['correct']} correct, {stats['skipped']} skipped")
    print(f"{'='*60}")

# Test on train set
print("\n" + "="*60)
print("TESTING ON TRAIN SET")
print("="*60)
train_results = test_solver_on_dataset(summary_files, 'train', test_these_examples)

# Test on test set
print("\n" + "="*60)
print("TESTING ON TEST SET")
print("="*60)
test_results = test_solver_on_dataset(summary_files, 'test', test_these_examples)

# Print summary
print_summary(train_results, 'train', test_these_examples, len(summary_files))
print_summary(test_results, 'test', test_these_examples, len(summary_files))
# Out:
# Found 101 summary files
#
# ============================================================
# TESTING ON TRAIN SET
# ============================================================
#
# Testing 7b3084d4_repair_selection_summary.txt:
# Error processing 7b3084d4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 7b3084d4 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 7b3084d4 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8f3a5a89_repair_selection_summary.txt:
# Error processing 8f3a5a89 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8f3a5a89 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 8f3a5a89 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7491f3cf_repair_selection_summary.txt:
# Error processing 7491f3cf example 0
#   Index 0: ✗ Error - ValueError
# Error processing 7491f3cf example 1
#   Index 1: ✗ Error - ValueError
# Error processing 7491f3cf example 2
#   Index 2: ✗ Error - ValueError
# Error processing 7491f3cf example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 53fb4810_repair_selection_summary.txt:
# Error processing 53fb4810 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 53fb4810 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b6f77b65_repair_selection_summary.txt:
# Error processing b6f77b65 example 0
#   Index 0: ✗ Error - ValueError
# Error processing b6f77b65 example 1
#   Index 1: ✗ Error - ValueError
# Error processing b6f77b65 example 2
#   Index 2: ✗ Error - ValueError
# Error processing b6f77b65 example 3
#   Index 3: ✗ Error - ValueError
# Error processing b6f77b65 example 4
#   Index 4: ✗ Error - ValueError
#   Index 5: SKIP (not available)
#
# Testing 332f06d7_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing c7f57c3e_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing eee78d87_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 409aa875_repair_selection_summary.txt:
# Error processing 409aa875 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 409aa875 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 409aa875 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 3e6067c3_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 64efde09_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7b80bb43_repair_selection_summary.txt:
# Error processing 7b80bb43 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 7b80bb43 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing fc7cae8d_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 35ab12c3_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: ✗ Error - ValueError
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 269e22fb_repair_selection_summary.txt:
# Error processing 269e22fb example 0
#   Index 0: ✗ Error - ValueError
# Error processing 269e22fb example 1
#   Index 1: ✗ Error - ValueError
# Error processing 269e22fb example 2
#   Index 2: ✗ Error - ValueError
# Error processing 269e22fb example 3
#   Index 3: ✗ Error - ValueError
# Error processing 269e22fb example 4
#   Index 4: ✗ Error - ValueError
#   Index 5: SKIP (not available)
#
# Testing 581f7754_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✗ Incorrect
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 221dfab4_repair_selection_summary.txt:
# Error processing 221dfab4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 221dfab4 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b99e7126_repair_selection_summary.txt:
# Error processing b99e7126 example 0
#   Index 0: ✗ Error - ValueError
# Error processing b99e7126 example 1
#   Index 1: ✗ Error - ValueError
# Error processing b99e7126 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7b5033c1_repair_selection_summary.txt:
# Error processing 7b5033c1 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 7b5033c1 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 800d221b_repair_selection_summary.txt:
# Error processing 800d221b example 0
#   Index 0: ✗ Error - ValueError
# Error processing 800d221b example 1
#   Index 1: ✗ Error - ValueError
# Error processing 800d221b example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing f931b4a8_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: ✗ Incorrect
#   Index 4: ✗ Incorrect
#   Index 5: SKIP (not available)
#
# Testing e8686506_repair_selection_summary.txt:
# Error processing e8686506 example 0
#   Index 0: ✗ Error - ValueError
# Error processing e8686506 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing c4d067a0_repair_selection_summary.txt:
# Error processing c4d067a0 example 0
#   Index 0: ✗ Error - ValueError
# Error processing c4d067a0 example 1
#   Index 1: ✗ Error - ValueError
# Error processing c4d067a0 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 71e489b6_repair_selection_summary.txt:
# Error processing 71e489b6 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 71e489b6 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 71e489b6 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8f215267_repair_selection_summary.txt:
# Error processing 8f215267 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8f215267 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 8f215267 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing dd6b8c4b_repair_selection_summary.txt:
# Error processing dd6b8c4b example 0
#   Index 0: ✗ Error - ValueError
# Error processing dd6b8c4b example 1
#   Index 1: ✗ Error - ValueError
# Error processing dd6b8c4b example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 247ef758_repair_selection_summary.txt:
# Error processing 247ef758 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 247ef758 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 247ef758 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 446ef5d2_repair_selection_summary.txt:
# Error processing 446ef5d2 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 446ef5d2 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing d35bdbdc_repair_selection_summary.txt:
# Error processing d35bdbdc example 0
#   Index 0: ✗ Error - ValueError
# Error processing d35bdbdc example 1
#   Index 1: ✗ Error - ValueError
# Error processing d35bdbdc example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 88e364bc_repair_selection_summary.txt:
# Error processing 88e364bc example 0
#   Index 0: ✗ Error - ValueError
# Error processing 88e364bc example 1
#   Index 1: ✗ Error - ValueError
# Error processing 88e364bc example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 0934a4d8_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✗ Incorrect
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b0039139_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 62593bfd_repair_selection_summary.txt:
# Error processing 62593bfd example 0
#   Index 0: ✗ Error - ValueError
# Error processing 62593bfd example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b5ca7ac4_repair_selection_summary.txt:
# Error processing b5ca7ac4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing b5ca7ac4 example 1
#   Index 1: ✗ Error - ValueError
# Error processing b5ca7ac4 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7b0280bc_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# Skipping e87109e9_repair_selection_summary.txt: markers not found
#
# Testing 65b59efc_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8b7bacbf_repair_selection_summary.txt:
# Error processing 8b7bacbf example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8b7bacbf example 1
#   Index 1: ✗ Error - ValueError
# Error processing 8b7bacbf example 2
#   Index 2: ✗ Error - ValueError
# Error processing 8b7bacbf example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 5961cc34_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing cb2d8a2c_repair_selection_summary.txt:
# Error processing cb2d8a2c example 0
#   Index 0: ✗ Error - ValueError
# Error processing cb2d8a2c example 1
#   Index 1: ✗ Error - ValueError
# Error processing cb2d8a2c example 2
#   Index 2: ✗ Error - ValueError
# Error processing cb2d8a2c example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 271d71e2_repair_selection_summary.txt:
# Error processing 271d71e2 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 271d71e2 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 271d71e2 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 6ffbe589_repair_selection_summary.txt:
# Error processing 6ffbe589 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 6ffbe589 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 6ffbe589 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8698868d_repair_selection_summary.txt:
# Error processing 8698868d example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8698868d example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 78332cb0_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing dfadab01_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 6e4f6532_repair_selection_summary.txt:
# Error processing 6e4f6532 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 6e4f6532 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing faa9f03d_repair_selection_summary.txt:
# Error processing faa9f03d example 0
#   Index 0: ✗ Error - ValueError
# Error processing faa9f03d example 1
#   Index 1: ✗ Error - ValueError
# Error processing faa9f03d example 2
#   Index 2: ✗ Error - ValueError
# Error processing faa9f03d example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing dbff022c_repair_selection_summary.txt:
# Error processing dbff022c example 0
#   Index 0: ✗ Error - ValueError
# Error processing dbff022c example 1
#   Index 1: ✗ Error - ValueError
# Error processing dbff022c example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8e5c0c38_repair_selection_summary.txt:
# Error processing 8e5c0c38 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8e5c0c38 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a6f40cea_repair_selection_summary.txt:
# Error processing a6f40cea example 0
#   Index 0: ✗ Error - ValueError
# Error processing a6f40cea example 1
#   Index 1: ✗ Error - ValueError
# Error processing a6f40cea example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 97d7923e_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# ✗ e3721c99_repair_selection_summary.txt: Fatal error - NameError: name 'typing' is not defined
#
# Testing 2b83f449_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing d59b0160_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing f560132c_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 67e490f4_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 9385bd28_repair_selection_summary.txt:
# Error processing 9385bd28 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 9385bd28 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 9385bd28 example 2
#   Index 2: ✗ Error - ValueError
# Error processing 9385bd28 example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 142ca369_repair_selection_summary.txt:
# Error processing 142ca369 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 142ca369 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 142ca369 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a47bf94d_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 20270e3b_repair_selection_summary.txt:
# Error processing 20270e3b example 0
#   Index 0: ✗ Error - ValueError
# Error processing 20270e3b example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: ✓ Correct
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 21897d95_repair_selection_summary.txt:
# Error processing 21897d95 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 21897d95 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 21897d95 example 2
#   Index 2: ✗ Error - ValueError
# Error processing 21897d95 example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 31f7f899_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 4c416de3_repair_selection_summary.txt:
# Error processing 4c416de3 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 4c416de3 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 4c416de3 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 4c7dc4dd_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 9aaea919_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 2c181942_repair_selection_summary.txt:
# Error processing 2c181942 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 2c181942 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 2c181942 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 88bcf3b4_repair_selection_summary.txt:
# Error processing 88bcf3b4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 88bcf3b4 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 88bcf3b4 example 2
#   Index 2: ✗ Error - ValueError
# Error processing 88bcf3b4 example 3
#   Index 3: ✗ Error - ValueError
# Error processing 88bcf3b4 example 4
#   Index 4: ✗ Error - ValueError
#   Index 5: SKIP (not available)
#
# Testing a395ee82_repair_selection_summary.txt:
# Error processing a395ee82 example 0
#   Index 0: ✗ Error - ValueError
# Error processing a395ee82 example 1
#   Index 1: ✗ Error - ValueError
# Error processing a395ee82 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 195c6913_repair_selection_summary.txt:
# Error processing 195c6913 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 195c6913 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 195c6913 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8b9c3697_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 3a25b0d8_repair_selection_summary.txt:
# Error processing 3a25b0d8 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 3a25b0d8 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b9e38dc0_repair_selection_summary.txt:
# Error processing b9e38dc0 example 0
#   Index 0: ✗ Error - ValueError
# Error processing b9e38dc0 example 1
#   Index 1: ✗ Error - ValueError
# Error processing b9e38dc0 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing da515329_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing e12f9a14_repair_selection_summary.txt:
# Error processing e12f9a14 example 0
#   Index 0: ✗ Error - ValueError
# Error processing e12f9a14 example 1
#   Index 1: ✗ Error - ValueError
# Error processing e12f9a14 example 2
#   Index 2: ✗ Error - ValueError
# Error processing e12f9a14 example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 9bbf930d_repair_selection_summary.txt:
# Error processing 9bbf930d example 0
#   Index 0: ✗ Error - ValueError
# Error processing 9bbf930d example 1
#   Index 1: ✗ Error - ValueError
# Error processing 9bbf930d example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a32d8b75_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a251c730_repair_selection_summary.txt:
# Error processing a251c730 example 0
#   Index 0: ✗ Error - ValueError
# Error processing a251c730 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 16de56c4_repair_selection_summary.txt:
# Error processing 16de56c4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 16de56c4 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# ✗ de809cff_repair_selection_summary.txt: Fatal error - NameError: name 'typing' is not defined
#
# Testing b10624e5_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 89565ca0_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a25697e4_repair_selection_summary.txt:
# Error processing a25697e4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing a25697e4 example 1
#   Index 1: ✗ Error - ValueError
# Error processing a25697e4 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 135a2760_repair_selection_summary.txt:
# Error processing 135a2760 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 135a2760 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7666fa5d_repair_selection_summary.txt:
# Error processing 7666fa5d example 0
#   Index 0: ✗ Error - ValueError
# Error processing 7666fa5d example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing e376de54_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
# Error processing e376de54 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 16b78196_repair_selection_summary.txt:
# Error processing 16b78196 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 16b78196 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 80a900e0_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing edb79dae_repair_selection_summary.txt:
# Error processing edb79dae example 0
#   Index 0: ✗ Error - ValueError
# Error processing edb79dae example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 3dc255db_repair_selection_summary.txt:
# Error processing 3dc255db example 0
#   Index 0: ✗ Error - ValueError
# Error processing 3dc255db example 1
#   Index 1: ✗ Error - ValueError
# Error processing 3dc255db example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing cbebaa4b_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 1ae2feb7_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing d8e07eb2_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✗ Incorrect
#   Index 3: ✗ Incorrect
#   Index 4: ✗ Incorrect
#   Index 5: SKIP (not available)
#
# Testing 28a6681f_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: ✓ Correct
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# ✗ 20a9e565_repair_selection_summary.txt: Fatal error - NameError: name 'Set' is not defined
#
# Testing 5545f144_repair_selection_summary.txt:
# Error processing 5545f144 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 5545f144 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 5545f144 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 2d0172a1_repair_selection_summary.txt:
# Error processing 2d0172a1 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 2d0172a1 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 2d0172a1 example 2
#   Index 2: ✗ Error - ValueError
# Error processing 2d0172a1 example 3
#   Index 3: ✗ Error - ValueError
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 13e47133_repair_selection_summary.txt:
# Error processing 13e47133 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 13e47133 example 1
#   Index 1: ✗ Error - ValueError
# Error processing 13e47133 example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 898e7135_repair_selection_summary.txt:
# Error processing 898e7135 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 898e7135 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 4e34c42c_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing abc82100_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✗ Incorrect
#   Index 2: ✗ Incorrect
#   Index 3: ✓ Correct
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 5dbc8537_repair_selection_summary.txt:
# Error processing 5dbc8537 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 5dbc8537 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
#
# Testing 7b3084d4_repair_selection_summary.txt:
# Error processing 7b3084d4 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8f3a5a89_repair_selection_summary.txt:
# Error processing 8f3a5a89 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7491f3cf_repair_selection_summary.txt:
# Error processing 7491f3cf example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 53fb4810_repair_selection_summary.txt:
# Error processing 53fb4810 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b6f77b65_repair_selection_summary.txt:
# Error processing b6f77b65 example 0
#   Index 0: ✗ Error - ValueError
# Error processing b6f77b65 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 332f06d7_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing c7f57c3e_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing eee78d87_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 409aa875_repair_selection_summary.txt:
# Error processing 409aa875 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 3e6067c3_repair_selection_summary.txt:
#   Index 0: ✓ Correct
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 64efde09_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7b80bb43_repair_selection_summary.txt:
# Error processing 7b80bb43 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing fc7cae8d_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 35ab12c3_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 269e22fb_repair_selection_summary.txt:
# Error processing 269e22fb example 0
#   Index 0: ✗ Error - ValueError
# Error processing 269e22fb example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 581f7754_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✓ Correct
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 221dfab4_repair_selection_summary.txt:
# Error processing 221dfab4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 221dfab4 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b99e7126_repair_selection_summary.txt:
# Error processing b99e7126 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7b5033c1_repair_selection_summary.txt:
# Error processing 7b5033c1 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 800d221b_repair_selection_summary.txt:
# Error processing 800d221b example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing f931b4a8_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing e8686506_repair_selection_summary.txt:
# Error processing e8686506 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing c4d067a0_repair_selection_summary.txt:
# Error processing c4d067a0 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 71e489b6_repair_selection_summary.txt:
# Error processing 71e489b6 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 71e489b6 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8f215267_repair_selection_summary.txt:
# Error processing 8f215267 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing dd6b8c4b_repair_selection_summary.txt:
# Error processing dd6b8c4b example 0
#   Index 0: ✗ Error - ValueError
# Error processing dd6b8c4b example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 247ef758_repair_selection_summary.txt:
# Error processing 247ef758 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 247ef758 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 446ef5d2_repair_selection_summary.txt:
# Error processing 446ef5d2 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 446ef5d2 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing d35bdbdc_repair_selection_summary.txt:
# Error processing d35bdbdc example 0
#   Index 0: ✗ Error - ValueError
# Error processing d35bdbdc example 1
#   Index 1: ✗ Error - ValueError
# Error processing d35bdbdc example 2
#   Index 2: ✗ Error - ValueError
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 88e364bc_repair_selection_summary.txt:
# Error processing 88e364bc example 0
#   Index 0: ✗ Error - ValueError
# Error processing 88e364bc example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 0934a4d8_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b0039139_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 62593bfd_repair_selection_summary.txt:
# Error processing 62593bfd example 0
#   Index 0: ✗ Error - ValueError
# Error processing 62593bfd example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b5ca7ac4_repair_selection_summary.txt:
# Error processing b5ca7ac4 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7b0280bc_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# Skipping e87109e9_repair_selection_summary.txt: markers not found
#
# Testing 65b59efc_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8b7bacbf_repair_selection_summary.txt:
# Error processing 8b7bacbf example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8b7bacbf example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 5961cc34_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing cb2d8a2c_repair_selection_summary.txt:
# Error processing cb2d8a2c example 0
#   Index 0: ✗ Error - ValueError
# Error processing cb2d8a2c example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 271d71e2_repair_selection_summary.txt:
# Error processing 271d71e2 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 6ffbe589_repair_selection_summary.txt:
# Error processing 6ffbe589 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8698868d_repair_selection_summary.txt:
# Error processing 8698868d example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 78332cb0_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing dfadab01_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 6e4f6532_repair_selection_summary.txt:
# Error processing 6e4f6532 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 6e4f6532 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing faa9f03d_repair_selection_summary.txt:
# Error processing faa9f03d example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing dbff022c_repair_selection_summary.txt:
# Error processing dbff022c example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8e5c0c38_repair_selection_summary.txt:
# Error processing 8e5c0c38 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 8e5c0c38 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a6f40cea_repair_selection_summary.txt:
# Error processing a6f40cea example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 97d7923e_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# ✗ e3721c99_repair_selection_summary.txt: Fatal error - NameError: name 'typing' is not defined
#
# Testing 2b83f449_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing d59b0160_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing f560132c_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 67e490f4_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 9385bd28_repair_selection_summary.txt:
# Error processing 9385bd28 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 9385bd28 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 142ca369_repair_selection_summary.txt:
# Error processing 142ca369 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 142ca369 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a47bf94d_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 20270e3b_repair_selection_summary.txt:
# Error processing 20270e3b example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 21897d95_repair_selection_summary.txt:
# Error processing 21897d95 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 21897d95 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 31f7f899_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 4c416de3_repair_selection_summary.txt:
# Error processing 4c416de3 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 4c7dc4dd_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 9aaea919_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 2c181942_repair_selection_summary.txt:
# Error processing 2c181942 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 88bcf3b4_repair_selection_summary.txt:
# Error processing 88bcf3b4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 88bcf3b4 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a395ee82_repair_selection_summary.txt:
# Error processing a395ee82 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 195c6913_repair_selection_summary.txt:
# Error processing 195c6913 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 195c6913 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 8b9c3697_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 3a25b0d8_repair_selection_summary.txt:
# Error processing 3a25b0d8 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 3a25b0d8 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing b9e38dc0_repair_selection_summary.txt:
# Error processing b9e38dc0 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing da515329_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing e12f9a14_repair_selection_summary.txt:
# Error processing e12f9a14 example 0
#   Index 0: ✗ Error - ValueError
# Error processing e12f9a14 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 9bbf930d_repair_selection_summary.txt:
# Error processing 9bbf930d example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a32d8b75_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a251c730_repair_selection_summary.txt:
# Error processing a251c730 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 16de56c4_repair_selection_summary.txt:
# Error processing 16de56c4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 16de56c4 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# ✗ de809cff_repair_selection_summary.txt: Fatal error - NameError: name 'typing' is not defined
#
# Testing b10624e5_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 89565ca0_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing a25697e4_repair_selection_summary.txt:
# Error processing a25697e4 example 0
#   Index 0: ✗ Error - ValueError
# Error processing a25697e4 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 135a2760_repair_selection_summary.txt:
# Error processing 135a2760 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 7666fa5d_repair_selection_summary.txt:
# Error processing 7666fa5d example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing e376de54_repair_selection_summary.txt:
# Error processing e376de54 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 16b78196_repair_selection_summary.txt:
# Error processing 16b78196 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 80a900e0_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing edb79dae_repair_selection_summary.txt:
# Error processing edb79dae example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 3dc255db_repair_selection_summary.txt:
# Error processing 3dc255db example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing cbebaa4b_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 1ae2feb7_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✓ Correct
#   Index 2: ✗ Incorrect
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing d8e07eb2_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: ✗ Incorrect
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 28a6681f_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
# ✗ 20a9e565_repair_selection_summary.txt: Fatal error - NameError: name 'Set' is not defined
#
# Testing 5545f144_repair_selection_summary.txt:
# Error processing 5545f144 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 2d0172a1_repair_selection_summary.txt:
# Error processing 2d0172a1 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 2d0172a1 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 13e47133_repair_selection_summary.txt:
# Error processing 13e47133 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 13e47133 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 898e7135_repair_selection_summary.txt:
# Error processing 898e7135 example 0
#   Index 0: ✗ Error - ValueError
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 4e34c42c_repair_selection_summary.txt:
#   Index 0: ✗ Error - ValueError
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing abc82100_repair_selection_summary.txt:
#   Index 0: ✗ Incorrect
#   Index 1: SKIP (not available)
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# Testing 5dbc8537_repair_selection_summary.txt:
# Error processing 5dbc8537 example 0
#   Index 0: ✗ Error - ValueError
# Error processing 5dbc8537 example 1
#   Index 1: ✗ Error - ValueError
#   Index 2: SKIP (not available)
#   Index 3: SKIP (not available)
#   Index 4: SKIP (not available)
#   Index 5: SKIP (not available)
#
# ============================================================
# SUMMARY FOR TRAIN SET:
# ============================================================
# Total files: 101
# Programs that executed without error for all examples: 34
# Programs with correct output for all examples: 16
#
# PER-EXAMPLE-INDEX BREAKDOWN:
#   Index 0: 37 executed, 26 correct, 0 skipped
#   Index 1: 35 executed, 22 correct, 0 skipped
#   Index 2: 28 executed, 16 correct, 28 skipped
#   Index 3: 9 executed, 7 correct, 77 skipped
#   Index 4: 2 executed, 0 correct, 92 skipped
#   Index 5: 0 executed, 0 correct, 97 skipped
# ============================================================
#
# ============================================================
# SUMMARY FOR TEST SET:
# ============================================================
# Total files: 101
# Programs that executed without error for all examples: 30
# Programs with correct output for all examples: 1
#
# PER-EXAMPLE-INDEX BREAKDOWN:
#   Index 0: 30 executed, 1 correct, 0 skipped
#   Index 1: 8 executed, 3 correct, 58 skipped
#   Index 2: 1 executed, 0 correct, 95 skipped
#   Index 3: 0 executed, 0 correct, 97 skipped
#   Index 4: 0 executed, 0 correct, 97 skipped
#   Index 5: 0 executed, 0 correct, 97 skipped
# ============================================================
